# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# !ls
# Out:
# Cargo.lock			      output_fast.mov
# Cargo.toml			      output_full.mov
# collect.py			      output_medium.mov
# coord_map_full_14119.exr	      output_slow.mov
# coord_map_full_55147.exr	      processing_errors.log
# explore_messages.ipynb		      run_from_gz_example.sh
# full_coord_count_map_u64_768x768.bin  run_from_zst_example.sh
# generate_all_videos.sh		      src
# images				      target
# images_evil_corrupt		      user_coords_raw_4_2025.csv
# map_explore.ipynb		      vids_backup
# output_extra_fast.mov

# %%
DIM = 768
coord_count_map = np.fromfile("full_coord_count_map_u64_768x768.bin", dtype=np.uint64).reshape((DIM, DIM))

# %%
coord_count_map.max()
# Out:
# np.uint64(1356350101)

# %%
coord_count_map.sum()
# Out:
# np.uint64(266399843338)

# %%
plt.figure(figsize = (32,32))
plt.imshow(np.log(coord_count_map.transpose()[:500,:500]))
plt.colorbar()
# Out:
# /tmp/ipykernel_998878/3202589384.py:2: RuntimeWarning: divide by zero encountered in log
#   plt.imshow(np.log(coord_count_map.transpose()[:500,:500]))

# %%
plt.figure(figsize = (32,32))
plt.imshow((coord_count_map.transpose()[:500,:500]) == 1)
plt.colorbar()
